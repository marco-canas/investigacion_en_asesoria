# %% [markdown]
# [Vículo para evaluar la asesoría](https://forms.gle/jpywXvAAJC9L9mws9)

# %% [markdown]
# # Prompt para diseño de función para toma de asistencia
#
# Dame una función de usuario de Python, para tomar asistencia en el espacio de asesoría, donde la función: consigne los datos tomados de asistencia en un archivo .xlsx. Te pido que la función le asigne un identificador corto a cada estudiante asistente a la asesoría, para que cada vez que asista de nuevo a la asesoría, no sea necesario preguntarle todos los datos sino solo ingresar el identificador o nombre corto para el estudiante y la dificultad o solicitud que lo trae al espacio de asesoría. Dame el diseño  de esta función, de tal manera que ella consigne, nombre del estudiante, correo o email, programa académico y dificultad o solicitud que lo trae al espacio a asesoría.

# %%
# Toma de asistencia rápida al espacio de asesoría  

from openpyxl import Workbook, load_workbook
import os  

def registrar_asistencia():
    """
    Función para registrar asistencia en un espacio de asesoría.
    Guarda nombre, correo, programa académico y dificultad/solicitud.
    El archivo se guarda y actualiza en la carpeta especificada.
    """

    # Ruta donde se guardará el archivo
    carpeta = r"C:\Users\marco\OneDrive - Universidad de Antioquia\Documentos\1_administracion\informes_jefe\renovacion_contrato_ocasional\asistencia_asesoria"
    archivo = os.path.join(carpeta, "asistencia.xlsx")

    # Crear carpeta si no existe
    os.makedirs(carpeta, exist_ok=True)

    # Verificar si existe el archivo, si no lo crea
    if os.path.exists(archivo):
        wb = load_workbook(archivo)
        ws = wb.active
    else:
        wb = Workbook()
        ws = wb.active
        ws.append(["ID", "Nombre", "Correo", "Programa", "Dificultad/Solicitud"])
    
    # Diccionario de estudiantes ya registrados (ID como clave)
    estudiantes = {}
    for row in ws.iter_rows(min_row=2, values_only=True):
        estudiantes[row[0]] = {"nombre": row[1], "correo": row[2], "programa": row[3]}
    
    # Pedir identificador o nombre corto
    identificador = input("Ingrese su identificador corto o nuevo ID: ").strip()
    
    if identificador in estudiantes:
        print(f"Bienvenido de nuevo {estudiantes[identificador]['nombre']}")
        dificultad = input("Ingrese la dificultad o solicitud que lo trae: ")
        ws.append([identificador, estudiantes[identificador]['nombre'], 
                   estudiantes[identificador]['correo'], 
                   estudiantes[identificador]['programa'], 
                   dificultad])
    else:
        print("Nuevo estudiante, por favor ingrese sus datos completos.")
        nombre = input("Nombre completo: ")
        correo = input("Correo electrónico: ")
        programa = input("Programa académico: ")
        dificultad = input("Ingrese la dificultad o solicitud que lo trae: ")
        
        estudiantes[identificador] = {"nombre": nombre, "correo": correo, "programa": programa}
        ws.append([identificador, nombre, correo, programa, dificultad])
    
    # Guardar cambios en la ruta indicada
    wb.save(archivo)
    print(f"Asistencia registrada en {archivo}")

# %%
registrar_asistencia()
# Out:
# Nuevo estudiante, por favor ingrese sus datos completos.
# Asistencia registrada en asistencia.xlsx

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml3/blob/main/tools_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml3/blob/main/tools_numpy.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ### [Vínculo al programa del curso:  ]()

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = ''>

# %% [markdown]
# Reconocimiento a las profesoras destacadas en enseñanza de la matemática en Colombia

# %%
def registrar_asistente():
    import csv
    import os
    from datetime import datetime

    # Solicitar información del asistente
    nombre = input("Ingrese el nombre del asistente: ")
    edad = input("Ingrese la edad del asistente: ")
    genero = input("Ingrese el género del asistente (M/F): ")
    correo = input("Ingrese el correo electrónico del asistente: ")
    curso = input("Ingrese el nombre del curso al que pertenece su inquietud: ")
    institucion = input("Ingrese la institución de donde viene: ")
    dificultad = input("Describa brevemente en qué consiste su dificultad: ")

    # Obtener la fecha actual en formato AAAA-MM-DD
    fecha = datetime.today().strftime('%Y-%m-%d')

    # Definir la ruta completa del archivo
    ruta_base = r"C:\Users\marco\Documentos\investigacion\investigacion_en_asesoria\2_secuencia_accion\3_Creacion_Comunidad_Aprendizaje"
    archivo = os.path.join(ruta_base, 'registro_asistentes.csv')
    encabezados = ['Nombre', 'Edad', 'Género', 'Correo', 'Curso', 'Institución', 'Dificultad', 'Fecha']

    # Verificar si la carpeta existe, si no, crearla
    if not os.path.exists(ruta_base):
        os.makedirs(ruta_base)

    # Verificar si el archivo ya existe
    archivo_existe = os.path.isfile(archivo)

    # Escribir los datos
    with open(archivo, 'a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=',')
        if not archivo_existe:
            writer.writerow(encabezados)
        writer.writerow([nombre, edad, genero, correo, curso, institucion, dificultad, fecha])

    print(f"Registro exitoso. Los datos se han guardado en: {archivo}")

# %%
registrar_asistente()

# %% [markdown]
# # Principios de mi labor docente

# %% [markdown]
# ## Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# <img src = 'https://resources.maneuveringthemiddle.com/wp-content/uploads/2020/07/04212706/1-5.png' width = 200>

# %% [markdown]
# # Metodología de Aprendizaje Basado en Problemas y Proyectos (ABPP)

# %% [markdown]
# <img src = 'https://www.unir.net/wp-content/uploads/2020/07/aprendizaje-problemas2-1-1-1-1.jpeg' width = 200>

# %% [markdown]
# # Desarrollo del pensamiento computacional con Lenguaje Python y R; y con archivos Markdown orientado a la formación en ciencia de datos

# %% [markdown]
# <img src = 'https://i.ytimg.com/vi/mcG_wcR4e6M/maxresdefault.jpg' width = 200>

# %% [markdown]
# # Principio de fomento a la ciencia abierta, enseñar en el acceso a los datos públicos y el uso de software de código abierto

# %% [markdown]
# <img src = 'https://unesdoc.unesco.org/in/rest/Thumb/image?id=p%3A%3Ausmarcdef_0000379949_spa&author=UNESCO&title=Recomendaci%C3%B3n+de+la+UNESCO+sobre+la+Ciencia+Abierta&year=2021&publisher=UNESCO&TypeOfDocument=UnescoPhysicalDocument&mat=PGD&ct=true&size=512&isPhysical=1' width = 200>

# %% [markdown]
# El enfoque STEAMS en educación preescolar, primaria y secundaria es una extensión del enfoque STEM (Ciencia, Tecnología, Ingeniería y Matemáticas) y su variante STEAM, que incorpora el Arte.

# %% [markdown]
# El enfoque STEAMS pretende desarrollar un aprendizaje **interdisciplinario** que integre estas áreas para fomentar un pensamiento más holístico y práctico.

# %% [markdown]
# # Y el enfoque de Teoría de Registros de Representación Semiótica (TRRS) de Raymond Duval

# %% [markdown]
# ## Título de la Asesoría:

# %% [markdown]
# A continuación se presentan **10 ejercicios de aplicación de funciones cuadráticas en contextos reales**, diseñados para que los estudiantes **resuelvan las ecuaciones factorizando o utilizando la fórmula general**.
#
# Las expresiones matemáticas están delimitadas con signo de dólar `$` para usarlas fácilmente en **Markdown o cuadernos Jupyter**.
#
# ---

# %% [markdown]
# # Ejercicios de aplicación de funciones cuadráticas
#
# ## 1. Lanzamiento de una pelota
#
# La altura de una pelota lanzada verticalmente está dada por
#
# $f(t) = -5t^2 + 20t + 2$
#
# donde $t$ está en segundos y la altura en metros.
#
# **Preguntas**
#
# 1. ¿En qué momento la pelota toca el suelo?
# 2. Resuelva la ecuación $f(t)=0$ utilizando **la fórmula general**.
#
# ---
#
# # 2. Área de un terreno rectangular
#
# Un agricultor tiene **40 metros de cerca** para construir un corral rectangular contra un muro, por lo que solo necesita cercar **tres lados**.
#
# Sea $x$ la longitud de los lados perpendiculares al muro.
#
# El área está dada por
#
# $A(x) = x(40 - 2x)$
#
# **Preguntas**
#
# 1. Determine para qué valores de $x$ el área es cero.
# 2. Resuelva la ecuación **factorizando**.
#
# ---
#
# # 3. Trayectoria de un proyectil
#
# La trayectoria de una pelota está modelada por
#
# $h(x) = -x^2 + 6x + 7$
#
# donde $x$ es la distancia horizontal y $h(x)$ la altura.
#
# **Preguntas**
#
# 1. Determine en qué puntos la pelota toca el suelo.
# 2. Resuelva la ecuación **factorizando**.
#
# ---
#
# # 4. Ingreso de una empresa
#
# El ingreso mensual de una empresa se modela por
#
# $I(x) = -2x^2 + 40x$
#
# donde $x$ es el número de productos vendidos (en cientos).
#
# **Preguntas**
#
# 1. Determine para qué valores de $x$ el ingreso es cero.
# 2. Resuelva **factorizando**.
#
# ---
#
# # 5. Altura de un cohete
#
# La altura de un cohete está dada por
#
# $h(t) = -4.9t^2 + 29.4t$
#
# **Preguntas**
#
# 1. Determine cuándo el cohete regresa al suelo.
# 2. Resuelva la ecuación $h(t)=0$ **factorizando**.
#
# ---
#
# # 6. Diseño de un jardín
#
# Un jardín rectangular tiene área
#
# $A(x) = x^2 - 9x + 20$
#
# **Preguntas**
#
# 1. Determine las dimensiones posibles del jardín si el área es cero.
# 2. Resuelva la ecuación **factorizando**.
#
# ---
#
# # 7. Movimiento de un objeto
#
# La posición de un objeto está dada por
#
# $s(t) = t^2 - 5t + 6$
#
# **Preguntas**
#
# 1. Determine los instantes en que el objeto pasa por la posición cero.
# 2. Resuelva la ecuación **factorizando**.
#
# ---
#
# # 8. Beneficio de una empresa
#
# El beneficio está modelado por
#
# $B(x) = x^2 - 10x + 16$
#
# **Preguntas**
#
# 1. Determine los valores de producción para los cuales el beneficio es cero.
# 2. Resuelva usando **factorización**.
#
# ---
#
# # 9. Altura de una piedra lanzada desde un edificio
#
# La altura está dada por
#
# $h(t) = -5t^2 + 15t + 20$
#
# **Preguntas**
#
# 1. Determine el momento en que la piedra toca el suelo.
# 2. Resuelva la ecuación utilizando **la fórmula general**.
#
# ---
#
# # 10. Área de un rectángulo variable
#
# El área de un rectángulo se modela mediante
#
# $A(x) = x^2 - 7x + 10$
#
# **Preguntas**
#
# 1. Determine los valores de $x$ que hacen que el área sea cero.
# 2. Resuelva **factorizando**.
#
# ---
#
# 💡 **Sugerencia didáctica**
#
# Después de resolverlos algebraicamente, puede pedir a los estudiantes:
#
# 1. **Graficar cada función cuadrática con Python**.
# 2. Verificar gráficamente que **las raíces coinciden con los ceros de la función**.
# 3. Interpretar el significado físico de esas raíces.
#
# ---
#
# Si quieres, también puedo prepararte **otros 10 problemas más realistas (tipo física, economía e ingeniería)** que funcionan **perfectamente para modelación con Python en clase**, incluso usando **pandas y matplotlib** para que los estudiantes visualicen las soluciones.

# %% [markdown]
# # Calendario académico

# %% [markdown]
# # Cursos que orienta el profesor Marco Julio Cañas Campillo en 2025
#
# 1. Cálculo Vectorial para Ingeniería Agropecuaria
# 2. Análisis Numérico para Licenciatura en Matemáticas.
# 3. Práctica Pedagógica V para Licenciatura en Educación Infantil
# 4. Fundamentos de Lógica para Licenciatura en Matemáticas.

# %% [markdown]
# # Horario de clases del profesor Marco
#
# * Lunes 8-12: Cálculo Vectorial
# * Martes 8-12 M: Fundamentos de Aritmética.
# * Miércoles 8 a 12 M: Fundamentos de la Lógica
# * Jueves 2 a 6 PM: Desarrollo del pensamiento matemático en la infancia.
# * Viernes 8 - 12 M: Desarrollo del pensamiento matemático en la infancia.
# * Sábados 8-12 Asesorías y espacio para retroalimentación y apoyo al trabajo independiente.

# %% [markdown]
# # Horarios de monitoría y asesoría
#
# Coordinador de los cursos de la Facultad de Educación para regiones:
#
# Andrés Vélez: regioneducacion.fedu@udea.edu.co
# Coordinador Regiones
# Facultad de Educación
# Universidad de Antioquia

# %% [markdown]
# ## Monitores
#
# * Manuel San Juan Serrano: Contactar escribiendo al correo: manuel.serrano1@udea.edu.co
# * Yeifry Sebastian Uribe: yeifry.uribe@udea.edu.co

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Cómo enseñar con cuadernos Jupyter](https://jupyter4edu.github.io/jupyter-edu-book/)
#
# * [Cómo enseñar matemáticas con calculadora Casio LA991 cw](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://bibliotecadigital.udea.edu.co/bitstream/10495/32857/4/ParraZapata_2024_DesarrolloPensamientoMatematico2aed_versionweb.pdf)
#
# * [CALCULO I DE UNA VARIABLE Ron Larson-Bruce Edwards. Mc Graw Hill. 9º Edición](https://www.academia.edu/42139251/CALCULO_I_DE_UNA_VARIABLE_Ron_Larson_Bruce_Edwards_Mc_Graw_Hill_9o_Edici%C3%B3n)

# %% [markdown]
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://bibliotecadigital.udea.edu.co/handle/10495/3010)
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html

# %% [markdown]
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.u-cursos.cl/ciencias/2011/1/MC110/1/material_docente/bajar?id_material=574722)

# %% [markdown]
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)

# %% [markdown]
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://14.139.161.31/OddSem-0822-1122/Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf)

# %% [markdown]
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.
